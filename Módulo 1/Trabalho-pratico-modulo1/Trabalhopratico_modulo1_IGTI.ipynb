# %% [markdown]
# # Importando as blibiotecas

# %%
from math import sqrt
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
X, y = make_blobs(n_samples=500, centers=20, random_state=999)
plt.scatter(X[:,0], X[:,1])

def optimal_number_of_clusters(wcss):
    x1, y1 = 1, wcss[0]
    x2, y2 = 19, wcss[len(wcss)-1]
    distances = []
    for i in range(len(wcss)):
        x0 = i + 1
        y0 = wcss[i]
        numerator = abs((y2-y1)*x0 - (x2-x1)*y0 + x2*y1 - y2*x1)
        denominator = sqrt((y2 - y1)**2 + (x2 - x1)**2)
        distances.append(numerator/denominator)
        return distances.index(max(distances)) + 1
        print(kmeans.cluster_centers_)

# %%
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
n = optimal_number_of_clusters(wcss)
print(n)
# Out:
# 1

# %%
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
    print("Numero de Clusters:" ,i,"\nWCSS" , kmeans.inertia_)
plt.plot(range(1, 20), wcss)
plt.plot([1, 19],[wcss[0], wcss[len(wcss)-1]])
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.grid()
plt.show()
# Out:
# Numero de Clusters: 1
# WCSS 31547.372471390485
# Numero de Clusters: 2
# WCSS 16949.214472147927
# Numero de Clusters: 3
# WCSS 9464.847250570496
# Numero de Clusters: 4
# WCSS 6005.101775346179
# Numero de Clusters: 5
# WCSS 4717.404091931214
# Numero de Clusters: 6
# WCSS 3662.6403286096665
# Numero de Clusters: 7
# WCSS 2976.0038976067435
# Numero de Clusters: 8
# WCSS 2490.8713955724124
# Numero de Clusters: 9
# WCSS 2050.782439450748
# Numero de Clusters: 10
# WCSS 1840.9236678933362
# Numero de Clusters: 11
# WCSS 1648.3340466009743
# Numero de Clusters: 12
# WCSS 1499.6657531591206
# Numero de Clusters: 13
# WCSS 1309.9279051756946
# Numero de Clusters: 14
# WCSS 1165.8358377065254
# Numero de Clusters: 15
# WCSS 1060.701627979635
# Numero de Clusters: 16
# WCSS 987.731135489373
# Numero de Clusters: 17
# WCSS 912.5380422096612
# Numero de Clusters: 18
# WCSS 841.7141405261868
# Numero de Clusters: 19
# WCSS 810.4413165402957
